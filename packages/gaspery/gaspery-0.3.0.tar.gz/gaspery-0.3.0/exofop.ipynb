# %% [markdown]
# This notebook is just so I have a number to quote in the intro of the manuscript.

# %%
import csv
import pandas as pd
import numpy as np

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)

path = '/Users/chrislam/Desktop/gaspery/'

# %%
exofop = pd.read_csv(path+'exofop.csv')

# %%
exofop.dropna(subset=['TOI']).drop_duplicates(subset=['TOI'])
# Out:
#        Row ID      TIC ID         TIC       TOI     Telescope Instrument  \
# 0       17221        4711         NaN  TOI 3129  FLWO (1.5 m)       TRES
# 16      17222       17361  cTOI 17361  TOI 3127  FLWO (1.5 m)       TRES
# 18      29253       47667         NaN  TOI 6560  FLWO (1.5 m)       TRES
# 49      25462      909930         NaN  TOI 5287  FLWO (1.5 m)       TRES
# 51       1147     1003831         NaN   TOI 564  FLWO (1.5 m)       TRES
# ...       ...         ...         ...       ...           ...        ...
# 24908   29287  1884091865         NaN  TOI 1697  FLWO (1.5 m)       TRES
# 24911   29043  1980725947         NaN  TOI 3625   Keck (10 m)      HIRES
# 24912   29044  2010186093         NaN  TOI 3571   Keck (10 m)      HIRES
# 24913   29045  2016376984         NaN  TOI 3920   Keck (10 m)      HIRES
# 24914   20664  2041563029         NaN  TOI 1427   NOT (2.6 m)       FIES
#
#       Spectral Resolution (R)      Wavelengh coverage SNR/resolution element  \
# ...

# %%
archive = pd.read_csv(path+'PS_2024.04.10_12.49.19.csv')
archive = archive.dropna(subset=['tic_id'])
archive['tic_id'] = archive['tic_id'].str.replace(r'TIC ', '', regex=True).astype(int)

#archive['tic_id'] = 
archive
# Out:
#            pl_name     hostname     tic_id  default_flag  sy_snum  sy_pnum  \
# 0         AU Mic b       AU Mic  441420236             1        1        3
# 1         AU Mic c       AU Mic  441420236             1        1        3
# 2       DS Tuc A b     DS Tuc A  410214986             1        2        1
# 3        GJ 1252 b      GJ 1252  370133522             1        1        1
# 4         GJ 143 b       GJ 143  279741379             1        1        2
# ..             ...          ...        ...           ...      ...      ...
# 427      WASP-18 c      WASP-18  100100827             1        2        2
# 428      WASP-84 c      WASP-84  350293646             1        1        2
# 429  WD 1856+534 b  WD 1856+534  267574918             1        3        1
# 430     Wolf 327 b     Wolf 327    4918918             1        1        1
# 431       pi Men c     HD 39091  261136679             1        1        3
#
#                discoverymethod  disc_year  \
# ...

# %%
list(exofop.merge(archive, how='inner', left_on='TIC ID', right_on='tic_id').columns)
# Out:
# ['Row ID',
#  'TIC ID',
#  'TIC',
#  'TOI',
#  'Telescope',
#  'Instrument',
#  'Spectral Resolution (R)',
#  'Wavelengh coverage',
#  'SNR/resolution element',
#  'SNR wavelength',
#  'Appropriate to PRVs',
#  'Obs Date',
#  'User',
#  'User ID',
#  'Group',
#  'Tag',
#  'Notes',
#  'pl_name',
#  'hostname',
#  'tic_id',
#  'default_flag',
#  'sy_snum',
#  'sy_pnum',
#  'discoverymethod',
#  'disc_year',
#  'disc_facility',
#  'soltype',
#  'pl_controv_flag',
#  'pl_refname',
#  'pl_orbper',
#  'pl_orbpererr1',
#  'pl_orbpererr2',
#  'pl_orbperlim',
#  'pl_orbsmax',
#  'pl_orbsmaxerr1',
#  'pl_orbsmaxerr2',
#  'pl_orbsmaxlim',
#  'pl_rade',
#  'pl_radeerr1',
#  'pl_radeerr2',
#  'pl_radelim',
#  'pl_radj',
#  'pl_radjerr1',
#  'pl_radjerr2',
#  'pl_radjlim',
#  'pl_bmasse',
#  'pl_bmasseerr1',
#  'pl_bmasseerr2',
#  'pl_bmasselim',
#  'pl_bmassj',
#  'pl_bmassjerr1',
#  'pl_bmassjerr2',
#  'pl_bmassjlim',
#  'pl_bmassprov',
#  'pl_orbeccen',
#  'pl_orbeccenerr1',
# ...

# %%
exofop.merge(archive, how='inner', left_on='TIC ID', right_on='tic_id').drop_duplicates(subset='pl_name')
# Out:
#       Row ID     TIC ID             TIC       TOI     Telescope Instrument  \
# 0       1147    1003831             NaN   TOI 564  FLWO (1.5 m)       TRES
# 3      19779    4646810             NaN   TOI 461   NOT (2.6 m)       FIES
# 4      19779    4646810             NaN   TOI 461   NOT (2.6 m)       FIES
# 37     26153    4918918    cTOI 4918918  TOI 5747  FLWO (1.5 m)       TRES
# 39     16724    7548817    cTOI 7548817  TOI 2583  FLWO (1.5 m)       TRES
# ...      ...        ...             ...       ...           ...        ...
# 3703   26092  466382581  cTOI 466382581  TOI 5803  FLWO (1.5 m)       TRES
# 3705    3944  467179528             NaN  TOI 1266  FLWO (1.5 m)       TRES
# 3706    3944  467179528             NaN  TOI 1266  FLWO (1.5 m)       TRES
# 3711    5832  468574941             NaN  TOI 2046  FLWO (1.5 m)       TRES
# 3714   15551  470381900             NaN  TOI 1696    IRTF (3 m)       SpeX
#
# ...
